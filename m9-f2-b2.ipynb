# %% [markdown]
# # Time Series Course — m9-f2 (block 2)
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
import xgboost as xgb
from sklearn.model_selection import TimeSeriesSplit

# Full XGBoost pipeline
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {
    'max_depth': 6, 'eta': 0.05, 'subsample': 0.8,
    'colsample_bytree': 0.8, 'objective': 'reg:squarederror',
    'eval_metric': 'mae', 'seed': 42
}
model = xgb.train(params, dtrain, num_boost_round=500,
                  evals=[(dtest, 'test')], early_stopping_rounds=20, verbose_eval=50)
preds = model.predict(dtest)
print(f"XGBoost MAE: ₹{mean_absolute_error(y_test, preds):.1f}k")
