# %% [markdown]
# # arch library for GARCH -- not available in Pyodide
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
# In practice, use the arch library
from arch import arch_model

model = arch_model(nifty_returns, vol='Garch', p=1, q=1, mean='AR', lags=1)
res = model.fit(disp='off')
print(res.summary())

# Forecast volatility 5 steps ahead
forecasts = res.forecast(horizon=5)
print(forecasts.variance.iloc[-1])
