# %% [markdown]
# # Time Series Course — m14-e2 (block 5)
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
# ARIMA entry (requires statsmodels — read only)
from statsmodels.tsa.arima.model import ARIMA

model_arima = ARIMA(y[:split + n_lags], order=(5, 1, 1))
fit = model_arima.fit()
arima_preds = fit.forecast(steps=len(y_te))
print(f"ARIMA MAE:  {np.mean(np.abs(y_te - arima_preds)):.1f}")
print(f"ARIMA RMSE: {np.sqrt(np.mean((y_te - arima_preds)**2)):.1f}")
