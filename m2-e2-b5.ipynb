# %% [markdown]
# # statsmodels.tsa.seasonal_decompose automates this. Use model='multiplicative' when seasonal amplitude grows with the level.
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
# statsmodels provides automated decomposition (cannot run in browser)
from statsmodels.tsa.seasonal import seasonal_decompose

# Multiplicative decomposition — the correct choice here
result = seasonal_decompose(y, model='multiplicative', period=12)
result.plot()
plt.tight_layout()
plt.show()

# Additive for comparison
result_add = seasonal_decompose(y, model='additive', period=12)
result_add.plot()
plt.tight_layout()
plt.show()
