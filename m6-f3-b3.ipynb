# %% [markdown]
# # Run on Colab -- statsmodels diagnostics
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
# statsmodels diagnostic suite -- one-liner
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(y, order=(1, 1, 1))
result = model.fit()

# This single call produces 4 diagnostic plots:
# 1. Standardized residuals, 2. Histogram + KDE,
# 3. QQ plot, 4. Correlogram (ACF of residuals)
result.plot_diagnostics(figsize=(12, 8))
plt.tight_layout()
plt.show()

# Ljung-Box test
from statsmodels.stats.diagnostic import acorr_ljungbox
lb = acorr_ljungbox(result.resid, lags=[5, 10, 15, 20])
print(lb)
