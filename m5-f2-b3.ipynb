# %% [markdown]
# # Run on Colab -- statsmodels is not available in Pyodide
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
# statsmodels: fit ARIMA(1,0,1) = ARMA(1,1)
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(y, order=(1, 0, 1))
result = model.fit()
print(result.summary())

# Forecast next 20 steps
forecast = result.forecast(steps=20)
print("Next 20 forecasts:", forecast.values)
