# %% [markdown]
# # GARCH fitting and forecasting with arch library
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
from arch import arch_model

model = arch_model(train, vol='Garch', p=1, q=1, mean='Zero')
res = model.fit(disp='off')
print(res.summary())

# Rolling forecast on test set
forecasts = res.forecast(horizon=1, start=800, method='recursive')
vol_forecast = np.sqrt(forecasts.variance.values[-len(test):, 0])

realized_vol = np.abs(test)  # proxy for realized vol

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(realized_vol, vol_forecast)
print(f"\nVolatility forecast MAE: {mae:.4f}")
