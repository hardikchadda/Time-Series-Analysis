# %% [markdown]
# # Run on Colab -- statsmodels adfuller
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
# statsmodels ADF test -- the production version
from statsmodels.tsa.stattools import adfuller

result = adfuller(price)
print(f"ADF Statistic: {result[0]:.4f}")
print(f"p-value:       {result[1]:.4f}")
print(f"Lags used:     {result[2]}")

result_diff = adfuller(np.diff(price))
print(f"\nAfter differencing:")
print(f"ADF Statistic: {result_diff[0]:.4f}")
print(f"p-value:       {result_diff[1]:.6f}")
