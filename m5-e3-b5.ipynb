# %% [markdown]
# # Run on Colab -- statsmodels plot functions
#
# _From the **Time Series & Forecasting** course on Zylo._
#
# Run all cells (`Runtime → Run all` or `Ctrl+F9`) to execute.

# %%
# statsmodels provides polished ACF/PACF plots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(1, 2, figsize=(10, 3))
plot_acf(ar2, lags=20, ax=axes[0], title='ACF')
plot_pacf(ar2, lags=20, ax=axes[1], title='PACF')
plt.tight_layout()
plt.show()
